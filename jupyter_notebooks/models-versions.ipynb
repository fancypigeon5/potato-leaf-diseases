# %% [markdown]
# # V1

# %% [markdown]
# ## settings
#
# - image size = (300, 300, 3)
# - Batch_size = 64
# - Epochs = 300
# - Earlystopping pacience = 25

# %%
def create_tf_model(input_shape):
    model = Sequential()

    model.add(Input(shape=input_shape))
    
    model.add(Conv2D(filters=32, kernel_size=(3, 3), strides= (2, 2), activation='relu', ))
    
    model.add(Conv2D(filters=64, kernel_size=(3, 3), strides= (2, 2), activation='relu', ))

    model.add(Conv2D(filters=128, kernel_size=(3, 3), strides= (2, 2), activation='relu', ))
    
    model.add(Flatten())

    model.add(Dense(512, activation='relu'))
    model.add(Dropout(0.5))

    model.add(Dense(len(train_set.class_indices), activation='softmax'))

    model.compile(loss='categorical_crossentropy',
                  optimizer=Adam(),
                  metrics=['accuracy'])

    return model

# %%
#### Train Set #### 

Found 998 images belonging to 3 classes.
[1m32/32[0m [32m━━━━━━━━━━━━━━━━━━━━[0m[37m[0m [1m2s[0m 73ms/step
---  Confusion Matrix  ---
                       Actual Bacteria Actual Healthy Actual Phytopthora
Prediction Bacteria                395              0                  0
Prediction Healthy                   2            292                  4
Prediction Phytopthora               1              8                296


---  Classification Report  ---
              precision    recall  f1-score   support

    Bacteria       1.00      0.99      1.00       398
     Healthy       0.98      0.97      0.98       300
 Phytopthora       0.97      0.99      0.98       300

    accuracy                           0.98       998
   macro avg       0.98      0.98      0.98       998
weighted avg       0.99      0.98      0.98       998
 

#### Validation Set #### 

Found 227 images belonging to 3 classes.
[1m8/8[0m [32m━━━━━━━━━━━━━━━━━━━━[0m[37m[0m [1m1s[0m 64ms/step
---  Confusion Matrix  ---
                       Actual Bacteria Actual Healthy Actual Phytopthora
Prediction Bacteria                110              6                  2
Prediction Healthy                   2             28                  5
Prediction Phytopthora               3              7                 64


---  Classification Report  ---
              precision    recall  f1-score   support

    Bacteria       0.93      0.96      0.94       115
     Healthy       0.80      0.68      0.74        41
 Phytopthora       0.86      0.90      0.88        71

    accuracy                           0.89       227
   macro avg       0.87      0.85      0.85       227
weighted avg       0.89      0.89      0.89       227
 

#### Test Set ####

Found 110 images belonging to 3 classes.
[1m4/4[0m [32m━━━━━━━━━━━━━━━━━━━━[0m[37m[0m [1m0s[0m 73ms/step
---  Confusion Matrix  ---
                       Actual Bacteria Actual Healthy Actual Phytopthora
Prediction Bacteria                 54              2                  5
Prediction Healthy                   0             16                  1
Prediction Phytopthora               2              2                 28


---  Classification Report  ---
              precision    recall  f1-score   support

    Bacteria       0.89      0.96      0.92        56
     Healthy       0.94      0.80      0.86        20
 Phytopthora       0.88      0.82      0.85        34

    accuracy                           0.89       110
   macro avg       0.90      0.86      0.88       110
weighted avg       0.89      0.89      0.89       110

# %% [markdown]
# # V2

# %% [markdown]
# ## settings
#
# - image size = (300, 300, 3)
# - Batch_size = 64
# - Epochs = 300
# - Earlystopping pacience = 25

# %%
def create_tf_model(input_shape):
    model = Sequential()

    model.add(Input(shape=input_shape))
    
    model.add(Conv2D(filters=32, kernel_size=(3, 3), strides= (2, 2), activation='relu', ))
    
    model.add(Conv2D(filters=64, kernel_size=(3, 3), strides= (2, 2), activation='relu', ))

    model.add(Conv2D(filters=128, kernel_size=(3, 3), strides= (2, 2), activation='relu', ))

    model.add(Conv2D(filters=256, kernel_size=(3, 3), strides= (2, 2), activation='relu', ))
    
    model.add(Flatten())

    model.add(Dense(512, activation='relu'))
    model.add(Dropout(0.5))

    model.add(Dense(len(train_set.class_indices), activation='softmax'))

    model.compile(loss='categorical_crossentropy',
                  optimizer=Adam(),
                  metrics=['accuracy'])

    return model

# %%
#### Train Set #### 

Found 998 images belonging to 3 classes.
[1m32/32[0m [32m━━━━━━━━━━━━━━━━━━━━[0m[37m[0m [1m2s[0m 70ms/step
---  Confusion Matrix  ---
                       Actual Bacteria Actual Healthy Actual Phytopthora
Prediction Bacteria                389              0                  5
Prediction Healthy                   4            295                  5
Prediction Phytopthora               5              5                290


---  Classification Report  ---
              precision    recall  f1-score   support

    Bacteria       0.99      0.98      0.98       398
     Healthy       0.97      0.98      0.98       300
 Phytopthora       0.97      0.97      0.97       300

    accuracy                           0.98       998
   macro avg       0.97      0.98      0.98       998
weighted avg       0.98      0.98      0.98       998
 

#### Validation Set #### 

Found 227 images belonging to 3 classes.
[1m8/8[0m [32m━━━━━━━━━━━━━━━━━━━━[0m[37m[0m [1m1s[0m 58ms/step
---  Confusion Matrix  ---
                       Actual Bacteria Actual Healthy Actual Phytopthora
Prediction Bacteria                108              1                  3
Prediction Healthy                   2             33                  3
Prediction Phytopthora               5              7                 65


---  Classification Report  ---
              precision    recall  f1-score   support

    Bacteria       0.96      0.94      0.95       115
     Healthy       0.87      0.80      0.84        41
 Phytopthora       0.84      0.92      0.88        71

    accuracy                           0.91       227
   macro avg       0.89      0.89      0.89       227
weighted avg       0.91      0.91      0.91       227
 

#### Test Set ####

Found 110 images belonging to 3 classes.
[1m4/4[0m [32m━━━━━━━━━━━━━━━━━━━━[0m[37m[0m [1m0s[0m 74ms/step
---  Confusion Matrix  ---
                       Actual Bacteria Actual Healthy Actual Phytopthora
Prediction Bacteria                 54              0                  4
Prediction Healthy                   1             18                  2
Prediction Phytopthora               1              2                 28


---  Classification Report  ---
              precision    recall  f1-score   support

    Bacteria       0.93      0.96      0.95        56
     Healthy       0.86      0.90      0.88        20
 Phytopthora       0.90      0.82      0.86        34

    accuracy                           0.91       110
   macro avg       0.90      0.90      0.90       110
weighted avg       0.91      0.91      0.91       110

# %% [markdown]
# # v3

# %% [markdown]
# ## settings
#
# - image size = (300, 300, 3)
# - Batch_size = 64
# - Epochs = 300
# - Earlystopping pacience = 25

# %%
def create_tf_model(input_shape):
    model = Sequential()

    model.add(Input(shape=input_shape))
    
    model.add(Conv2D(filters=32, kernel_size=(3, 3), strides= (2, 2), activation='relu', ))
    
    model.add(Conv2D(filters=64, kernel_size=(3, 3), strides= (2, 2), activation='relu', ))

    model.add(Conv2D(filters=128, kernel_size=(3, 3), strides= (2, 2), activation='relu', ))

    model.add(Conv2D(filters=128, kernel_size=(3, 3), strides= (2, 2), activation='relu', ))

    model.add(Conv2D(filters=256, kernel_size=(3, 3), strides= (2, 2), activation='relu', ))
    
    model.add(Flatten())

    model.add(Dense(512, activation='relu'))
    model.add(Dropout(0.5))

    model.add(Dense(len(train_set.class_indices), activation='softmax'))

    model.compile(loss='categorical_crossentropy',
                  optimizer=Adam(),
                  metrics=['accuracy'])

    return model

# %%
#### Train Set #### 

Found 998 images belonging to 3 classes.
[1m32/32[0m [32m━━━━━━━━━━━━━━━━━━━━[0m[37m[0m [1m2s[0m 59ms/step
---  Confusion Matrix  ---
                       Actual Bacteria Actual Healthy Actual Phytopthora
Prediction Bacteria                393             13                 60
Prediction Healthy                   4            281                  8
Prediction Phytopthora               1              6                232


---  Classification Report  ---
              precision    recall  f1-score   support

    Bacteria       0.84      0.99      0.91       398
     Healthy       0.96      0.94      0.95       300
 Phytopthora       0.97      0.77      0.86       300

    accuracy                           0.91       998
   macro avg       0.92      0.90      0.91       998
weighted avg       0.92      0.91      0.91       998
 

#### Validation Set #### 

Found 227 images belonging to 3 classes.
[1m8/8[0m [32m━━━━━━━━━━━━━━━━━━━━[0m[37m[0m [1m1s[0m 63ms/step
---  Confusion Matrix  ---
                       Actual Bacteria Actual Healthy Actual Phytopthora
Prediction Bacteria                111              4                 12
Prediction Healthy                   2             33                  3
Prediction Phytopthora               2              4                 56


---  Classification Report  ---
              precision    recall  f1-score   support

    Bacteria       0.87      0.97      0.92       115
     Healthy       0.87      0.80      0.84        41
 Phytopthora       0.90      0.79      0.84        71

    accuracy                           0.88       227
   macro avg       0.88      0.85      0.86       227
weighted avg       0.88      0.88      0.88       227
 

#### Test Set ####

Found 110 images belonging to 3 classes.
[1m4/4[0m [32m━━━━━━━━━━━━━━━━━━━━[0m[37m[0m [1m0s[0m 60ms/step
---  Confusion Matrix  ---
                       Actual Bacteria Actual Healthy Actual Phytopthora
Prediction Bacteria                 55              2                  8
Prediction Healthy                   0             18                  0
Prediction Phytopthora               1              0                 26


---  Classification Report  ---
              precision    recall  f1-score   support

    Bacteria       0.85      0.98      0.91        56
     Healthy       1.00      0.90      0.95        20
 Phytopthora       0.96      0.76      0.85        34

    accuracy                           0.90       110
   macro avg       0.94      0.88      0.90       110
weighted avg       0.91      0.90      0.90       110

# %% [markdown]
# ---

# %% [markdown]
# # V2.1

# %% [markdown]
# ## settings
#
# - image size = (150, 150, 3)
# - Batch_size = 64
# - Epochs = 300
# - Earlystopping pacience = 25

# %%
def create_tf_model(input_shape):
    model = Sequential()

    model.add(Input(shape=input_shape))

    model.add(Conv2D(filters=32, kernel_size=(3, 3), strides= (2, 2), activation='relu', ))
    
    model.add(Conv2D(filters=64, kernel_size=(3, 3), strides= (2, 2), activation='relu', ))

    model.add(Conv2D(filters=128, kernel_size=(3, 3), strides= (2, 2), activation='relu', ))

    model.add(Conv2D(filters=256, kernel_size=(3, 3), strides= (2, 2), activation='relu', ))
    
    model.add(Flatten())

    model.add(Dense(256, activation='relu'))
    model.add(Dropout(0.25))

    model.add(Dense(len(train_set.class_indices), activation='softmax'))

    model.compile(loss='categorical_crossentropy',
                  optimizer=Adam(),
                  metrics=['accuracy'])

    return model

# %%
#### Train Set #### 

Found 998 images belonging to 3 classes.
32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step
---  Confusion Matrix  ---
                       Actual Bacteria Actual Healthy Actual Phytopthora
Prediction Bacteria                388              0                  7
Prediction Healthy                   7            300                 18
Prediction Phytopthora               3              0                275


---  Classification Report  ---
              precision    recall  f1-score   support

    Bacteria       0.98      0.97      0.98       398
     Healthy       0.92      1.00      0.96       300
 Phytopthora       0.99      0.92      0.95       300

    accuracy                           0.96       998
   macro avg       0.96      0.96      0.96       998
weighted avg       0.97      0.96      0.96       998
 

#### Validation Set #### 

Found 227 images belonging to 3 classes.
8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
---  Confusion Matrix  ---
                       Actual Bacteria Actual Healthy Actual Phytopthora
Prediction Bacteria                109              1                  5
Prediction Healthy                   3             36                  6
Prediction Phytopthora               3              4                 60


---  Classification Report  ---
              precision    recall  f1-score   support

    Bacteria       0.95      0.95      0.95       115
     Healthy       0.80      0.88      0.84        41
 Phytopthora       0.90      0.85      0.87        71

    accuracy                           0.90       227
   macro avg       0.88      0.89      0.88       227
weighted avg       0.90      0.90      0.90       227
 

#### Test Set ####

Found 110 images belonging to 3 classes.
4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
---  Confusion Matrix  ---
                       Actual Bacteria Actual Healthy Actual Phytopthora
Prediction Bacteria                 54              0                  4
Prediction Healthy                   1             19                  4
Prediction Phytopthora               1              1                 26


---  Classification Report  ---
              precision    recall  f1-score   support

    Bacteria       0.93      0.96      0.95        56
     Healthy       0.79      0.95      0.86        20
 Phytopthora       0.93      0.76      0.84        34

    accuracy                           0.90       110
   macro avg       0.88      0.89      0.88       110
weighted avg       0.90      0.90      0.90       110

# %% [markdown]
# # v2.2

# %% [markdown]
# ## settings
#
# - image size = (150, 150, 3)
# - Batch_size = 64
# - Epochs = 300
# - Earlystopping pacience = 25

# %%
def create_tf_model(input_shape):
    model = Sequential()

    model.add(Input(shape=input_shape))

    model.add(Conv2D(filters=64, kernel_size=(3, 3), strides= (2, 2), activation='relu', ))
    
    model.add(Conv2D(filters=128, kernel_size=(3, 3), strides= (2, 2), activation='relu', ))

    model.add(Conv2D(filters=256, kernel_size=(3, 3), strides= (2, 2), activation='relu', ))

    model.add(Conv2D(filters=512, kernel_size=(3, 3), strides= (2, 2), activation='relu', ))
    
    model.add(Flatten())

    model.add(Dense(256, activation='relu'))
    model.add(Dropout(0.25))

    model.add(Dense(len(train_set.class_indices), activation='softmax'))

    model.compile(loss='categorical_crossentropy',
                  optimizer=Adam(),
                  metrics=['accuracy'])

    return model

# %%
#### Train Set #### 

Found 998 images belonging to 3 classes.
32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step
---  Confusion Matrix  ---
                       Actual Bacteria Actual Healthy Actual Phytopthora
Prediction Bacteria                392              6                  6
Prediction Healthy                   3            286                  6
Prediction Phytopthora               3              8                288


---  Classification Report  ---
              precision    recall  f1-score   support

    Bacteria       0.97      0.98      0.98       398
     Healthy       0.97      0.95      0.96       300
 Phytopthora       0.96      0.96      0.96       300

    accuracy                           0.97       998
   macro avg       0.97      0.97      0.97       998
weighted avg       0.97      0.97      0.97       998
 

#### Validation Set #### 

Found 227 images belonging to 3 classes.
8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
---  Confusion Matrix  ---
                       Actual Bacteria Actual Healthy Actual Phytopthora
Prediction Bacteria                109              1                  3
Prediction Healthy                   2             33                  5
Prediction Phytopthora               4              7                 63


---  Classification Report  ---
              precision    recall  f1-score   support

    Bacteria       0.96      0.95      0.96       115
     Healthy       0.82      0.80      0.81        41
 Phytopthora       0.85      0.89      0.87        71

    accuracy                           0.90       227
   macro avg       0.88      0.88      0.88       227
weighted avg       0.90      0.90      0.90       227
 

#### Test Set ####

Found 110 images belonging to 3 classes.
4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
---  Confusion Matrix  ---
                       Actual Bacteria Actual Healthy Actual Phytopthora
Prediction Bacteria                 52              0                  6
Prediction Healthy                   0             19                  3
Prediction Phytopthora               4              1                 25


---  Classification Report  ---
              precision    recall  f1-score   support

    Bacteria       0.90      0.93      0.91        56
     Healthy       0.86      0.95      0.90        20
 Phytopthora       0.83      0.74      0.78        34

    accuracy                           0.87       110
   macro avg       0.86      0.87      0.87       110
weighted avg       0.87      0.87      0.87       110

# %% [markdown]
# # v2.3

# %% [markdown]
# ## settings
#
# - image size = (150, 150, 3)
# - Batch_size = 64
# - Epochs = 300
# - Earlystopping pacience = 25

# %%
def create_tf_model(input_shape):
    model = Sequential()

    model.add(Input(shape=input_shape))

    model.add(Conv2D(filters=16, kernel_size=(3, 3), strides= (2, 2), activation='relu', ))
    
    model.add(Conv2D(filters=32, kernel_size=(3, 3), strides= (2, 2), activation='relu', ))

    model.add(Conv2D(filters=64, kernel_size=(3, 3), strides= (2, 2), activation='relu', ))

    model.add(Conv2D(filters=128, kernel_size=(3, 3), strides= (2, 2), activation='relu', ))
    
    model.add(Flatten())

    model.add(Dense(512, activation='relu'))
    model.add(Dropout(0.5))

    model.add(Dense(128, activation='relu'))
    model.add(Dropout(0.25))

    model.add(Dense(len(train_set.class_indices), activation='softmax'))

    model.compile(loss='categorical_crossentropy',
                  optimizer=Adam(),
                  metrics=['accuracy'])

    return model

# %%
#### Train Set #### 

Found 998 images belonging to 3 classes.
32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
---  Confusion Matrix  ---
                       Actual Bacteria Actual Healthy Actual Phytopthora
Prediction Bacteria                389              5                 17
Prediction Healthy                   7            285                  5
Prediction Phytopthora               2             10                278


---  Classification Report  ---
              precision    recall  f1-score   support

    Bacteria       0.95      0.98      0.96       398
     Healthy       0.96      0.95      0.95       300
 Phytopthora       0.96      0.93      0.94       300

    accuracy                           0.95       998
   macro avg       0.95      0.95      0.95       998
weighted avg       0.95      0.95      0.95       998
 

#### Validation Set #### 

Found 227 images belonging to 3 classes.
8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
---  Confusion Matrix  ---
                       Actual Bacteria Actual Healthy Actual Phytopthora
Prediction Bacteria                111              3                  6
Prediction Healthy                   3             32                  2
Prediction Phytopthora               1              6                 63


---  Classification Report  ---
              precision    recall  f1-score   support

    Bacteria       0.93      0.97      0.94       115
     Healthy       0.86      0.78      0.82        41
 Phytopthora       0.90      0.89      0.89        71

    accuracy                           0.91       227
   macro avg       0.90      0.88      0.89       227
weighted avg       0.91      0.91      0.91       227
 

#### Test Set ####

Found 110 images belonging to 3 classes.
4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step 
---  Confusion Matrix  ---
                       Actual Bacteria Actual Healthy Actual Phytopthora
Prediction Bacteria                 56              2                  4
Prediction Healthy                   0             17                  2
Prediction Phytopthora               0              1                 28


---  Classification Report  ---
              precision    recall  f1-score   support

    Bacteria       0.90      1.00      0.95        56
     Healthy       0.89      0.85      0.87        20
 Phytopthora       0.97      0.82      0.89        34

    accuracy                           0.92       110
   macro avg       0.92      0.89      0.90       110
weighted avg       0.92      0.92      0.92       110

# %% [markdown]
# # V2.4

# %% [markdown]
# ## settings
#
# - image size = (150, 150, 3)
# - Batch_size = 64
# - Epochs = 300
# - Earlystopping pacience = 25

# %%
def create_tf_model(input_shape):
    model = Sequential()

    model.add(Input(shape=input_shape))

    model.add(Conv2D(filters=16, kernel_size=(3, 3), strides= (2, 2), activation='relu', ))
    
    model.add(Conv2D(filters=32, kernel_size=(3, 3), strides= (2, 2), activation='relu', ))

    model.add(Conv2D(filters=64, kernel_size=(3, 3), strides= (2, 2), activation='relu', ))

    model.add(Conv2D(filters=256, kernel_size=(3, 3), strides= (2, 2), activation='relu', ))
    
    model.add(Flatten())

    model.add(Dense(256, activation='relu'))
    model.add(Dropout(0.25))

    model.add(Dense(64, activation='relu'))
    model.add(Dropout(0.25))

    model.add(Dense(len(train_set.class_indices), activation='softmax'))

    model.compile(loss='categorical_crossentropy',
                  optimizer=Adam(),
                  metrics=['accuracy'])

    return model

# %%
#### Train Set #### 

Found 998 images belonging to 3 classes.
32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
---  Confusion Matrix  ---
                       Actual Bacteria Actual Healthy Actual Phytopthora
Prediction Bacteria                394              0                  5
Prediction Healthy                   4            299                  2
Prediction Phytopthora               0              1                293


---  Classification Report  ---
              precision    recall  f1-score   support

    Bacteria       0.99      0.99      0.99       398
     Healthy       0.98      1.00      0.99       300
 Phytopthora       1.00      0.98      0.99       300

    accuracy                           0.99       998
   macro avg       0.99      0.99      0.99       998
weighted avg       0.99      0.99      0.99       998
 

#### Validation Set #### 

Found 227 images belonging to 3 classes.
8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
---  Confusion Matrix  ---
                       Actual Bacteria Actual Healthy Actual Phytopthora
Prediction Bacteria                110              2                  4
Prediction Healthy                   2             33                  5
Prediction Phytopthora               3              6                 62


---  Classification Report  ---
              precision    recall  f1-score   support

    Bacteria       0.95      0.96      0.95       115
     Healthy       0.82      0.80      0.81        41
 Phytopthora       0.87      0.87      0.87        71

    accuracy                           0.90       227
   macro avg       0.88      0.88      0.88       227
weighted avg       0.90      0.90      0.90       227
 

#### Test Set ####

Found 110 images belonging to 3 classes.
4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step 
---  Confusion Matrix  ---
                       Actual Bacteria Actual Healthy Actual Phytopthora
Prediction Bacteria                 55              0                  5
Prediction Healthy                   1             18                  1
Prediction Phytopthora               0              2                 28


---  Classification Report  ---
              precision    recall  f1-score   support

    Bacteria       0.92      0.98      0.95        56
     Healthy       0.90      0.90      0.90        20
 Phytopthora       0.93      0.82      0.88        34

    accuracy                           0.92       110
   macro avg       0.92      0.90      0.91       110
weighted avg       0.92      0.92      0.92       110
